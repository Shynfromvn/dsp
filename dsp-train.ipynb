# %%
# !pip install gdown
# !pip install tensorboardX numpy torch torchvision scikit-image opencv-python h5py matplotlib efficientnet_pytorch einops timm yacs batchgenerators medpy nibabel SimpleITK

# %%
# %cd /kaggle/working/
# !rm -rf /kaggle/working/*
# !git clone https://github.com/Shynfromvn/dsp.git SSL4MIS
# Out:
# /kaggle/working
# Cloning into 'SSL4MIS'...
# remote: Enumerating objects: 1808, done.
# remote: Counting objects: 100% (1808/1808), done.
# remote: Compressing objects: 100% (675/675), done.
# remote: Total 1808 (delta 1127), reused 1807 (delta 1126), pack-reused 0 (from 0)
# Receiving objects: 100% (1808/1808), 529.79 KiB | 5.70 MiB/s, done.
# Resolving deltas: 100% (1127/1127), done.

# %%
import gdown

#https://drive.google.com/file/d/18225R5VrhepZuTJIMGr5X_syFS_NmM66/view?usp=drive_link
file_id = "18225R5VrhepZuTJIMGr5X_syFS_NmM66"  # Replace this with your file's ID
output_file = "data.zip"  # Replace "data_file.ext" with the desired output filename and extension

gdown.download(f"https://drive.google.com/uc?id={file_id}", output_file)

file_id = "16b2paVzOwlk3UOGlDyYsDWmP0ZDza-83"  # Replace this with your file's ID
output_file = "ACDC.zip"  # Replace "data_file.ext" with the desired output filename and extension
gdown.download(f"https://drive.google.com/uc?id={file_id}", output_file)
# !rm -rf /kaggle/working/SSL4MIS/data/BraTS2019/data
# !unzip -o /kaggle/working/data.zip -d /kaggle/working/SSL4MIS/data/BraTS2019

# !rm -rf /kaggle/working/SSL4MIS/data/ACDC/data
# !unzip -o /kaggle/working/ACDC.zip -d /kaggle/working/SSL4MIS/data

# %%
import torch
print(f"CUDA available: {torch.cuda.is_available()}")
print(f"GPU count: {torch.cuda.device_count()}")
# Out:
# CUDA available: True
# GPU count: 2

# %% [markdown]
# **BASE LINE HERE**

# %%
# # UAMT baseline
# %cd /kaggle/working/SSL4MIS/code
# !CUDA_VISIBLE_DEVICES=0 python train_uncertainty_aware_mean_teacher_2D.py --root_path ../data/ACDC --exp ACDC/Uncertainty_Aware_Mean_Teacher_1 --num_classes 4 --labeled_num 7 --max_iterations 1000 --model unet & CUDA_VISIBLE_DEVICES=1 python train_uncertainty_aware_mean_teacher_2D.py --root_path ../data/ACDC --exp ACDC/Uncertainty_Aware_Mean_Teacher_2 --num_classes 4 --labeled_num 7 --max_iterations 1000 --model unet
# !CUDA_VISIBLE_DEVICES=0 python train_uncertainty_aware_mean_teacher_2D.py --root_path ../data/ACDC --exp ACDC/Uncertainty_Aware_Mean_Teacher_3 --num_classes 4 --labeled_num 7 --max_iterations 1000 --model unet & CUDA_VISIBLE_DEVICES=1 python train_uncertainty_aware_mean_teacher_2D.py --root_path ../data/ACDC --exp ACDC/Uncertainty_Aware_Mean_Teacher_4 --num_classes 4 --labeled_num 7 --max_iterations 1000 --model unet
# Out:
# /kaggle/working/SSL4MIS/code
# /usr/local/lib/python3.12/dist-packages/google/cloud/aiplatform/models.py:52: FutureWarning: Support for google-cloud-storage < 3.0.0 will be removed in a future version of google-cloud-aiplatform. Please upgrade to google-cloud-storage >= 3.0.0.
#   from google.cloud.aiplatform.utils import gcs_utils
# /usr/local/lib/python3.12/dist-packages/google/cloud/aiplatform/models.py:52: FutureWarning: Support for google-cloud-storage < 3.0.0 will be removed in a future version of google-cloud-aiplatform. Please upgrade to google-cloud-storage >= 3.0.0.
#   from google.cloud.aiplatform.utils import gcs_utils
# ...

# %%
# %cd /kaggle/working/SSL4MIS/code
# !CUDA_VISIBLE_DEVICES=0 python test_2D_fully.py --root_path ../data/ACDC --exp ACDC/Uncertainty_Aware_Mean_Teacher_1 --model unet --num_classes 4 --labeled_num 7
# !CUDA_VISIBLE_DEVICES=0 python test_2D_fully.py --root_path ../data/ACDC --exp ACDC/Uncertainty_Aware_Mean_Teacher_2 --model unet --num_classes 4 --labeled_num 7
# !CUDA_VISIBLE_DEVICES=0 python test_2D_fully.py --root_path ../data/ACDC --exp ACDC/Uncertainty_Aware_Mean_Teacher_3 --model unet --num_classes 4 --labeled_num 7
# !CUDA_VISIBLE_DEVICES=0 python test_2D_fully.py --root_path ../data/ACDC --exp ACDC/Uncertainty_Aware_Mean_Teacher_4 --model unet --num_classes 4 --labeled_num 7
# Out:
# /kaggle/working/SSL4MIS/code
# Traceback (most recent call last):
#   File "/kaggle/working/SSL4MIS/code/test_2D_fully.py", line 10, in <module>
#     from medpy import metric
# ModuleNotFoundError: No module named 'medpy'
# Traceback (most recent call last):
#   File "/kaggle/working/SSL4MIS/code/test_2D_fully.py", line 10, in <module>
#     from medpy import metric
# ModuleNotFoundError: No module named 'medpy'
# Traceback (most recent call last):
#   File "/kaggle/working/SSL4MIS/code/test_2D_fully.py", line 10, in <module>
#     from medpy import metric
# ModuleNotFoundError: No module named 'medpy'
# Traceback (most recent call last):
#   File "/kaggle/working/SSL4MIS/code/test_2D_fully.py", line 10, in <module>
#     from medpy import metric
# ModuleNotFoundError: No module named 'medpy'

# %% [markdown]
# **Your modification start below**

# %%
# Your modification with UAMT
# %cd /kaggle/working/SSL4MIS/code
# !CUDA_VISIBLE_DEVICES=0 python re_code.py --root_path ../data/ACDC --exp ACDC/Uncertainty_Aware_Mean_Teacher_ffc_1 --num_classes 4 --labeled_num 7 --max_iterations 10000 --model unet & CUDA_VISIBLE_DEVICES=1 python re_code.py --root_path ../data/ACDC --exp ACDC/Uncertainty_Aware_Mean_Teacher_ffc_2 --num_classes 4 --labeled_num 7 --max_iterations 10000 --model unet
# !CUDA_VISIBLE_DEVICES=0 python re_code.py --root_path ../data/ACDC --exp ACDC/Uncertainty_Aware_Mean_Teacher_ffc_3 --num_classes 4 --labeled_num 7 --max_iterations 10000 --model unet & CUDA_VISIBLE_DEVICES=1 python re_code.py --root_path ../data/ACDC --exp ACDC/Uncertainty_Aware_Mean_Teacher_ffc_4 --num_classes 4 --labeled_num 7 --max_iterations 10000 --model unet

# %%
# %cd /kaggle/working/SSL4MIS/code
# !python test_2D_improved.py --root_path ../data/ACDC --exp ACDC/Uncertainty_Aware_Mean_Teacher_ffc_1 --num_classes 4 --labeled_num 7 --model unet
# !python test_2D_improved.py --root_path ../data/ACDC --exp ACDC/Uncertainty_Aware_Mean_Teacher_ffc_2 --num_classes 4 --labeled_num 7 --model unet
# !python test_2D_improved.py --root_path ../data/ACDC --exp ACDC/Uncertainty_Aware_Mean_Teacher_ffc_3 --num_classes 4 --labeled_num 7 --model unet
# !python test_2D_improved.py --root_path ../data/ACDC --exp ACDC/Uncertainty_Aware_Mean_Teacher_ffc_4 --num_classes 4 --labeled_num 7 --model unet

# %% [markdown]
# Calculate number of parameters

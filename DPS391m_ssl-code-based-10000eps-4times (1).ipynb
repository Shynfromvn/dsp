# %%
# !pip install gdown
# !pip install tensorboardX numpy torch torchvision scikit-image opencv-python h5py matplotlib efficientnet_pytorch einops timm yacs batchgenerators medpy nibabel
# Out:
# ^C
# Collecting gdown
#   Downloading gdown-5.2.1-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: beautifulsoup4 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from gdown) (4.12.3)
# Requirement already satisfied: filelock in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from gdown) (3.16.1)
# Requirement already satisfied: requests[socks] in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from gdown) (2.32.3)
# Requirement already satisfied: tqdm in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from gdown) (4.66.5)
# Requirement already satisfied: soupsieve>1.2 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from beautifulsoup4->gdown) (2.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from requests[socks]->gdown) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from requests[socks]->gdown) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from requests[socks]->gdown) (1.26.20)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from requests[socks]->gdown) (2024.2.2)
# Collecting PySocks!=1.5.7,>=1.5.6 (from requests[socks]->gdown)
#   Using cached PySocks-1.7.1-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: colorama in c:\users\admin\appdata\roaming\python\python311\site-packages (from tqdm->gdown) (0.4.6)
# Downloading gdown-5.2.1-py3-none-any.whl (18 kB)
# Using cached PySocks-1.7.1-py3-none-any.whl (16 kB)
# Installing collected packages: PySocks, gdown
# Successfully installed PySocks-1.7.1 gdown-5.2.1
# [notice] A new release of pip is available: 25.0.1 -> 26.0
# [notice] To update, run: C:\Users\admin\AppData\Local\Programs\Python\Python311\python.exe -m pip install --upgrade pip

# %%
# %cd /kaggle/working/
# !rm -rf /kaggle/working/*
# !git clone https://github.com/Shynfromvn/dsp.git SSL4MIS

# %%
import gdown

#https://drive.google.com/file/d/18225R5VrhepZuTJIMGr5X_syFS_NmM66/view?usp=drive_link
file_id = "18225R5VrhepZuTJIMGr5X_syFS_NmM66"  # Replace this with your file's ID
output_file = "data.zip"  # Replace "data_file.ext" with the desired output filename and extension

gdown.download(f"https://drive.google.com/uc?id={file_id}", output_file)

file_id = "16b2paVzOwlk3UOGlDyYsDWmP0ZDza-83"  # Replace this with your file's ID
output_file = "ACDC.zip"  # Replace "data_file.ext" with the desired output filename and extension
gdown.download(f"https://drive.google.com/uc?id={file_id}", output_file)
# !rm -rf /kaggle/working/SSL4MIS/data/BraTS2019/data
# !unzip -o /kaggle/working/data.zip -d /kaggle/working/SSL4MIS/data/BraTS2019

# !rm -rf /kaggle/working/SSL4MIS/data/ACDC/data
# !unzip -o /kaggle/working/ACDC.zip -d /kaggle/working/SSL4MIS/data

# %% [markdown]
# **BASE LINE HERE**

# %%
# UAMT baseline
# %cd /kaggle/working/SSL4MIS/code
# !CUDA_VISIBLE_DEVICES=0 python train_uncertainty_aware_mean_teacher_2D.py --root_path ../data/ACDC --exp ACDC/Uncertainty_Aware_Mean_Teacher_1 --num_classes 4 --labeled_num 7 --max_iterations 1000 --model unet & CUDA_VISIBLE_DEVICES=1 python train_uncertainty_aware_mean_teacher_2D.py --root_path ../data/ACDC --exp ACDC/Uncertainty_Aware_Mean_Teacher_2 --num_classes 4 --labeled_num 7 --max_iterations 1000 --model unet
# !CUDA_VISIBLE_DEVICES=0 python train_uncertainty_aware_mean_teacher_2D.py --root_path ../data/ACDC --exp ACDC/Uncertainty_Aware_Mean_Teacher_3 --num_classes 4 --labeled_num 7 --max_iterations 1000 --model unet & CUDA_VISIBLE_DEVICES=1 python train_uncertainty_aware_mean_teacher_2D.py --root_path ../data/ACDC --exp ACDC/Uncertainty_Aware_Mean_Teacher_4 --num_classes 4 --labeled_num 7 --max_iterations 1000 --model unet

# %%
# %cd /kaggle/working/SSL4MIS/code
# !CUDA_VISIBLE_DEVICES=0 python test_2D_fully.py --root_path ../data/ACDC --exp ACDC/Uncertainty_Aware_Mean_Teacher_1 --model unet --num_classes 4 --labeled_num 7
# !CUDA_VISIBLE_DEVICES=0 python test_2D_fully.py --root_path ../data/ACDC --exp ACDC/Uncertainty_Aware_Mean_Teacher_2 --model unet --num_classes 4 --labeled_num 7
# !CUDA_VISIBLE_DEVICES=0 python test_2D_fully.py --root_path ../data/ACDC --exp ACDC/Uncertainty_Aware_Mean_Teacher_3 --model unet --num_classes 4 --labeled_num 7
# !CUDA_VISIBLE_DEVICES=0 python test_2D_fully.py --root_path ../data/ACDC --exp ACDC/Uncertainty_Aware_Mean_Teacher_4 --model unet --num_classes 4 --labeled_num 7

# %% [markdown]
# **Your modification start below**

# %%
# Your modification with UAMT
# %cd /kaggle/working/SSL4MIS/code
# !CUDA_VISIBLE_DEVICES=0 python re_code.py --root_path ../data/ACDC --exp ACDC/Uncertainty_Aware_Mean_Teacher_ffc_1 --num_classes 4 --labeled_num 7 --max_iterations 1000 --model unet & CUDA_VISIBLE_DEVICES=1 python re_code.py --root_path ../data/ACDC --exp ACDC/Uncertainty_Aware_Mean_Teacher_ffc_2 --num_classes 4 --labeled_num 7 --max_iterations 1000 --model unet
# !CUDA_VISIBLE_DEVICES=0 python re_code.py --root_path ../data/ACDC --exp ACDC/Uncertainty_Aware_Mean_Teacher_ffc_3 --num_classes 4 --labeled_num 7 --max_iterations 1000 --model unet & CUDA_VISIBLE_DEVICES=1 python re_code.py --root_path ../data/ACDC --exp ACDC/Uncertainty_Aware_Mean_Teacher_ffc_4 --num_classes 4 --labeled_num 7 --max_iterations 1000 --model unet

# %%
# %cd /kaggle/working/SSL4MIS/code
# !CUDA_VISIBLE_DEVICES=0 python test_2D_fully.py --root_path ../data/ACDC --exp ACDC/Uncertainty_Aware_Mean_Teacher_ffc_1 --num_classes 4 --labeled_num 7 --model unet
# !CUDA_VISIBLE_DEVICES=0 python test_2D_fully.py --root_path ../data/ACDC --exp ACDC/Uncertainty_Aware_Mean_Teacher_ffc_2 --num_classes 4 --labeled_num 7 --model unet
# !CUDA_VISIBLE_DEVICES=0 python test_2D_fully.py --root_path ../data/ACDC --exp ACDC/Uncertainty_Aware_Mean_Teacher_ffc_3 --num_classes 4 --labeled_num 7 --model unet
# !CUDA_VISIBLE_DEVICES=0 python test_2D_fully.py --root_path ../data/ACDC --exp ACDC/Uncertainty_Aware_Mean_Teacher_ffc_4 --num_classes 4 --labeled_num 7 --model unet

# %% [markdown]
# Calculate number of parameters

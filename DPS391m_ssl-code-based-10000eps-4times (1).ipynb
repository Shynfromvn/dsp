# %%
# !pip install gdown
# !pip install tensorboardX numpy torch torchvision scikit-image opencv-python h5py matplotlib efficientnet_pytorch einops timm yacs batchgenerators medpy nibabel

# %%
# %cd /kaggle/working/
# !rm -rf /kaggle/working/*
# !git clone https://github.com/HiLab-git/SSL4MIS.git

# %%
import gdown

#https://drive.google.com/file/d/18225R5VrhepZuTJIMGr5X_syFS_NmM66/view?usp=drive_link
file_id = "18225R5VrhepZuTJIMGr5X_syFS_NmM66"  # Replace this with your file's ID
output_file = "data.zip"  # Replace "data_file.ext" with the desired output filename and extension

gdown.download(f"https://drive.google.com/uc?id={file_id}", output_file)

file_id = "16b2paVzOwlk3UOGlDyYsDWmP0ZDza-83"  # Replace this with your file's ID
output_file = "ACDC.zip"  # Replace "data_file.ext" with the desired output filename and extension
gdown.download(f"https://drive.google.com/uc?id={file_id}", output_file)
# !rm -rf /kaggle/working/SSL4MIS/data/BraTS2019/data
# !unzip -o /kaggle/working/data.zip -d /kaggle/working/SSL4MIS/data/BraTS2019

# !rm -rf /kaggle/working/SSL4MIS/data/ACDC/data
# !unzip -o /kaggle/working/ACDC.zip -d /kaggle/working/SSL4MIS/data

# %% [markdown]
# **BASE LINE HERE**

# %%
#baseline
# %cd /kaggle/working/SSL4MIS/code
# !CUDA_VISIBLE_DEVICES=0 python train_uncertainty_rectified_pyramid_consistency_2D.py --root_path ../data/ACDC --exp ACDC/Uncertainty_Rectified_Pyramid_Consistency_1 --num_classes 4 --labeled_num 7 --max_iterations 10000 & CUDA_VISIBLE_DEVICES=1 python train_uncertainty_rectified_pyramid_consistency_2D.py --root_path ../data/ACDC --exp ACDC/Uncertainty_Rectified_Pyramid_Consistency_2 --num_classes 4 --labeled_num 7 --max_iterations 10000
# !CUDA_VISIBLE_DEVICES=0 python train_uncertainty_rectified_pyramid_consistency_2D.py --root_path ../data/ACDC --exp ACDC/Uncertainty_Rectified_Pyramid_Consistency_3 --num_classes 4 --labeled_num 7 --max_iterations 10000 & CUDA_VISIBLE_DEVICES=1 python train_uncertainty_rectified_pyramid_consistency_2D.py --root_path ../data/ACDC --exp ACDC/Uncertainty_Rectified_Pyramid_Consistency_4 --num_classes 4 --labeled_num 7 --max_iterations 10000

# %%
# %cd /kaggle/working/SSL4MIS/code
# !CUDA_VISIBLE_DEVICES=0 python test_2D_fully.py --root_path ../data/ACDC --exp ACDC/Uncertainty_Rectified_Pyramid_Consistency_1 --model unet_urpc --num_classes 4 --labeled_num 7
# !CUDA_VISIBLE_DEVICES=0 python test_2D_fully.py --root_path ../data/ACDC --exp ACDC/Uncertainty_Rectified_Pyramid_Consistency_2 --model unet_urpc --num_classes 4 --labeled_num 7
# !CUDA_VISIBLE_DEVICES=0 python test_2D_fully.py --root_path ../data/ACDC --exp ACDC/Uncertainty_Rectified_Pyramid_Consistency_3 --model unet_urpc --num_classes 4 --labeled_num 7
# !CUDA_VISIBLE_DEVICES=0 python test_2D_fully.py --root_path ../data/ACDC --exp ACDC/Uncertainty_Rectified_Pyramid_Consistency_4 --model unet_urpc --num_classes 4 --labeled_num 7

# %% [markdown]
# **Your modification start below**

# %%
# ffc
# %cd /kaggle/working/SSL4MIS/code
# !CUDA_VISIBLE_DEVICES=0 python train_uncertainty_rectified_pyramid_consistency_2D.py --root_path ../data/ACDC --exp ACDC/Uncertainty_Rectified_Pyramid_Consistency_ffc_1 --num_classes 4 --labeled_num 7 --max_iterations 10000 --model NAME_OF_YOUR_MODEL & CUDA_VISIBLE_DEVICES=1 python train_uncertainty_rectified_pyramid_consistency_2D.py --root_path ../data/ACDC --exp ACDC/Uncertainty_Rectified_Pyramid_Consistency_ffc_2 --num_classes 4 --labeled_num 7 --max_iterations 10000 --model NAME_OF_YOUR_MODEL
# !CUDA_VISIBLE_DEVICES=0 python train_uncertainty_rectified_pyramid_consistency_2D.py --root_path ../data/ACDC --exp ACDC/Uncertainty_Rectified_Pyramid_Consistency_ffc_3 --num_classes 4 --labeled_num 7 --max_iterations 10000 --model NAME_OF_YOUR_MODEL & CUDA_VISIBLE_DEVICES=1 python train_uncertainty_rectified_pyramid_consistency_2D.py --root_path ../data/ACDC --exp ACDC/Uncertainty_Rectified_Pyramid_Consistency_ffc_4 --num_classes 4 --labeled_num 7 --max_iterations 10000 --model NAME_OF_YOUR_MODEL

# %%
# %cd /kaggle/working/SSL4MIS/code
# !CUDA_VISIBLE_DEVICES=0 python test_2D_fully.py --root_path ../data/ACDC --exp ACDC/Uncertainty_Rectified_Pyramid_Consistency_ffc_1 --num_classes 4 --labeled_num 7 --model NAME_OF_YOUR_MODEL
# !CUDA_VISIBLE_DEVICES=0 python test_2D_fully.py --root_path ../data/ACDC --exp ACDC/Uncertainty_Rectified_Pyramid_Consistency_ffc_2 --num_classes 4 --labeled_num 7 --model NAME_OF_YOUR_MODEL
# !CUDA_VISIBLE_DEVICES=0 python test_2D_fully.py --root_path ../data/ACDC --exp ACDC/Uncertainty_Rectified_Pyramid_Consistency_ffc_3 --num_classes 4 --labeled_num 7 --model NAME_OF_YOUR_MODEL
# !CUDA_VISIBLE_DEVICES=0 python test_2D_fully.py --root_path ../data/ACDC --exp ACDC/Uncertainty_Rectified_Pyramid_Consistency_ffc_4 --num_classes 4 --labeled_num 7 --model NAME_OF_YOUR_MODEL

# %% [markdown]
# Calculate number of parameters
